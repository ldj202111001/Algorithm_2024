# %% [markdown]
# # 1. 문제정의
# 기수 정렬 알고리즘을 구현하라.

# %% [markdown]
# # 2. 알고리즘 설명
# 1. 각 킷값의 빈도수를 저장하기 위한 리스트를 만든다.
# 2. 각 킷값의 항목이 리스트에 몇번 나타났는지 빈도수를 계산한다.
# 3. 빈도수가 구해지면 빈도테이블을 이용해 위치 테이블을 만든다.
# 4. 위치 테이블을 이용해 가장 작은 킷값부터 순서대로 빈도수만큼 나열한다.

# %% [markdown]
# # 3. 손으로 푼 예제
# ![6.2_hand.png](attachment:6.2_hand.png)

# %% [markdown]
# # 4. 코드 설명
# #### 1. 자료구조 정의
# output:
# 정렬할 수 들을 저장할 큐의 최대 갯수
#
#
# count:
# 각 킷값의 빈도수를 저장하는 인덱스
# 7행의 연산으로 '위치 테이블' 로 전환된다.
#
# data:
# 정렬할 수 들의 리스트

# %% [markdown]
# # 5. 알고리즘 코드

# %%
def counting_sort(A):
    output = [0] * len(A) # 정렬된 결과 리스트 임시 저장
    count = [0] * MAX_VAL # 각 킷값의 빈도를 저장하는 인덱스


    for i in A:
        count[i] += 1     # 리스트 data의 각 킷값의 빈도수 계산


    for i in range(MAX_VAL):
        count[i] += count[i-1] # 전 빈도수를 다음빈도수에 더한다 즉, 빈도테이블을 위치 테이블로 전환하는 과정이다.
                               # 위치 테이블: 인덱스 = 킷값, 값 = 결과 리스트[값] 이전까지 인덱스 저장
    for i in range(len(A)):
        output[count[A[i]] - 1] = A[i] # 위치 테이블을 토대로 결과 리스트에 리스트 정렬
        count[A[i]] -= 1


    for i in range(len(A)):
        A[i] = output[i]    # 결과 리스트를 원래 리스트에 저장

       


MAX_VAL = 10
data = [1, 4, 1, 2, 7, 5, 2]
print("Original : ", data)
counting_sort(data)
print("Counting : ", data)
# Out:
# Original :  [1, 4, 1, 2, 7, 5, 2]
# Counting :  [1, 1, 2, 2, 4, 5, 7]

# %% [markdown]
# # 6. 테스트 코드 (입력을 바꾸어)

# %%
def counting_sort(A):
    output = [0] * len(A) # 정렬된 결과 리스트 임시 저장
    count = [0] * MAX_VAL # 각 킷값의 빈도를 저장하는 인덱스


    for i in A:
        count[i] += 1     # 리스트 data의 각 킷값의 빈도수 계산


    for i in range(MAX_VAL):
        count[i] += count[i-1] # 전 빈도수를 다음빈도수에 더한다 즉, 빈도테이블을 위치 테이블로 전환하는 과정이다.
                               # 위치 테이블: 인덱스 = 킷값, 값 = 결과 리스트[값] 이전까지 인덱스 저장
    for i in range(len(A)):
        output[count[A[i]] - 1] = A[i] # 위치 테이블을 토대로 결과 리스트에 리스트 정렬
        count[A[i]] -= 1


    for i in range(len(A)):
        A[i] = output[i]    # 결과 리스트를 원래 리스트에 저장

       
   


MAX_VAL = 11
data = [5, 3, 4, 4, 9, 1, 6, 1, 4, 3, 2, 6]
print("Original : ", data)
counting_sort(data)
print("Counting : ", data)
# Out:
# Original :  [5, 3, 4, 4, 9, 1, 6, 1, 4, 3, 2, 6]
# Counting :  [1, 1, 2, 3, 3, 4, 4, 4, 5, 6, 6, 9]

# %% [markdown]
# # 7. 수행 결과

# %% [markdown]
# ![6.1_output.png](attachment:6.1_output.png)

# %% [markdown]
# # 8. 복잡도 분석
# ### 시간 복잡도:
# 입력의 크기가 n일때, 숫자의 범위가 k가지 라면,
# 입력 리스트의 빈도수 계산을 위해 모든 리스트를 한번씩 순회해야 하므로 n번,
# 위치 테이블 구현을 위해 숫자의 범위 만큼 순회해야 하므로 k번,
# 전체 알고리즘은 O(k+n) 즉, O(n) 의 시간복잡도를 갖는다.
