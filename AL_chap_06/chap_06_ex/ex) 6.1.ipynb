# %% [markdown]
# # 1. 문제정의
# 기수 정렬 알고리즘을 구현하라.

# %% [markdown]
# # 2. 알고리즘 설명
# #### (한 자릿수일 경우)
# 1. 정렬할 수 들을 저장할 버킷들을 준비한다. (버킷의 크기는 10이다.)
# 2. 정렬할 수 들을 숫자에 맞게 큐 형식으로 버킷에 넣는다.
# 3. 오름차순 정렬 일 경우 위쪽 버킷부터 버킷안에 있는 숫자를 전부 출력한다.
# #### (여러 자리 숫자일 경우)
# 버킷을 이용하여 낮은 자릿수 부터 정렬한 다음 차츰 높은 자릿수로 정렬한다.

# %% [markdown]
# # 3. 손으로 푼 예제
# ![6.1_hand.png](attachment:6.1_hand.png)

# %% [markdown]
# # 4. 코드 설명
# #### 1. 자료구조 정의
# BUCKETS:
# 정렬할 수 들을 저장할 큐의 최대 갯수
#
# DIGITS:
# 정렬할 수 들의 최대 자릿수
#
# data:
# 정렬하 수 들의 리스트
#
#
# #### 2. 함수 정의
# def radix_sort(A):
# 매개변수: 정렬할 수 들의 리스트
# 함수 내용: 매개변수로써 전달받은 리스트를 기수 정렬을 이용해 정렬한다.

# %% [markdown]
# # 5. 알고리즘 코드

# %%
from queue import Queue
def radix_sort(A):
    queues = []
    for i in range(BUCKETS):
        queues.append(Queue())
    n = len(A)
    factor = 1
    for d in range(DIGITS):
        for i in range(n):
            queues[(A[i]//factor) % BUCKETS].put(A[i])
        j = 0
        for b in range(BUCKETS):
            while not queues[b].empty():
                A[j] = queues[b].get()
                j += 1
        factor *= BUCKETS
        print("step", d+1, A)


import random
BUCKETS = 10
DIGITS = 4
data = []
for i in range(10):
    data.append(random.randint(1,9999))
radix_sort(data)
print("Radix: ", data)
# Out:
# step 1 [2230, 7031, 8101, 2951, 8491, 9743, 5493, 7845, 6826, 5516]
# step 2 [8101, 5516, 6826, 2230, 7031, 9743, 7845, 2951, 8491, 5493]
# step 3 [7031, 8101, 2230, 8491, 5493, 5516, 9743, 6826, 7845, 2951]
# step 4 [2230, 2951, 5493, 5516, 6826, 7031, 7845, 8101, 8491, 9743]
# Radix:  [2230, 2951, 5493, 5516, 6826, 7031, 7845, 8101, 8491, 9743]

# %% [markdown]
# # 6. 테스트 코드 (입력을 바꾸어)
#
# (입력을 난수로 하기 때문에 테스트 코드 필요없음)

# %% [markdown]
# # 7. 수행 결과

# %% [markdown]
# ![6.1_output.png](attachment:6.1_output.png)

# %% [markdown]
# # 8. 복잡도 분석
# 입력의 개수가 n개이고, 숫자의 최대 d개의 자릿수를 가진다고 할때,
# O(dn) 즉, O(n)의 시간복잡도를 가진다.
